# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis

# %% [markdown]
# ###  Observations from the drugs study results:

# %% [markdown]
# - The drug, Capomulin, shows a promising sign in reducing the tumor in mouse over a 45 days period. It would be interesting to see if the drug can cure cancer if continued past 45 days.
# - There is an almost equal representation of both male and female mouse. Hence the data is not skewed towards any gender.
# - Capomulin and Ramicane were both equally effective in reducing the tumor volume assuming that the initial tumor volume were same for both the drugs. Capomulin and Ramicane also had slightly higher datapoints compared to other drugs in the study.
# - With a correlation of 0.84, mouse weight had a strong positive correlation with average tumor volume. Hence, reducing the weight of the mouse could be one of the steps towards reducing the tumor volume.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_trial_df = pd.DataFrame.merge(mouse_metadata, study_results, on="Mouse ID")

# Display the data table for preview
mouse_trial_df

#print(mouse_trial_df.to_string())
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
number_of_mice = mouse_trial_df["Mouse ID"].nunique()

number_of_mice
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint.

duplicate_df = mouse_trial_df[mouse_trial_df.duplicated(subset=['Mouse ID','Timepoint'])]
duplicate_df


mouseID_unique=duplicate_df["Mouse ID"].unique()
mouseID_unique
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 

mouse_trial_df[mouse_trial_df["Mouse ID"] == 'g989']
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.

clean_mouseID_df = mouse_trial_df[mouse_trial_df['Mouse ID'] != 'g989']
clean_mouseID_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.

mice_num_dup = clean_mouseID_df["Mouse ID"].nunique()
mice_num_dup
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 

mean_tumor = clean_mouseID_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].mean()

median_tumor = clean_mouseID_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].median()


variance_tumor = clean_mouseID_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].var()


std_tumor = clean_mouseID_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].std()

sem_tumor = clean_mouseID_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].sem()


# Assemble the resulting series into a single summary dataframe.
tumor_summary_df = pd.DataFrame({'Mean Tumor Volume':mean_tumor,
                                     'Median Tumor Volume':median_tumor,
                                     'Tumor Volume Variance':variance_tumor,
                                    'Tumor Volume Std. Dev.':std_tumor,
                                'Tumor Volume Std. Err.':sem_tumor})
tumor_summary_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line

# Method 1

clean_mouseID_df.groupby(['Drug Regimen']).agg({'Tumor Volume (mm3)': ["mean", "median", "var", "std", "sem"]})

#Method 2

# clean_mouseID_df.groupby('Drug Regimen').agg(

    
#         Mean_Tumor_Volume=('Tumor Volume (mm3)', "mean"),
    
#         Median_Tumor_Volume=('Tumor Volume (mm3)', "median"),
    
#         Tumor_Volume_Variance=('Tumor Volume (mm3)', "var"),
    
#         Tumor_Volume_Std_Dev=('Tumor Volume (mm3)', "std"),
        
#         Tumor_Volume_Std_Err=('Tumor Volume (mm3)', "sem")
# )
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pandas.
#Group original clean df by Drug Regimen
drugs_group=clean_mouseID_df.groupby(["Drug Regimen"]).count()

#Reset the index
drugs_group_reset = pd.DataFrame(drugs_group).reset_index()

#Create a datframe with Drug Regimen and Mouse ID 
drugs_df = drugs_group_reset[["Drug Regimen", "Mouse ID"]].sort_values('Mouse ID', ascending=False)

drugs_df_index = drugs_df.set_index("Drug Regimen")

#Create the bar chart
drugs_plot = drugs_df_index.plot(kind='bar',  title= 'No. of Unique Mice per Drug Regimen', legend =False, alpha = 0.75)

drugs_plot.set_ylabel('Number of Unique Mice Tested')

plt.savefig("Images/BarChart_Pandas.png")
plt.show()

# %%
# Generate a bar plot showing the total number of unqiue mice tested on each drug regimen using using pyplot.

#Get x & y values to be plotted
x_axis = drugs_df.iloc[:,0]
y_axis = drugs_df.iloc[:,1]

#Plot the bar chart
plt.figure(figsize=(9,8))
plt.bar(x_axis, y_axis, facecolor='b', width=0.5, alpha=0.75, align = 'center')

# Set a Title and labels
plt.title('No. of Unique Mice per Drug Regimen', fontsize=16)
plt.xlabel('Drug Regimen', fontsize=14)
plt.ylabel('Number of Unique Mice Tested', fontsize=14) 
plt.xticks(rotation='vertical', fontsize=12)

# Set x and y limits
plt.xlim(-0.7, len(x_axis)-0.3)
plt.ylim(0, max(y_axis)*1.05)

# Save the figure
plt.savefig("Images/BarChart_Pyplot.png")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

# First create a dataframe grouping by the 'Sex' column and get count for each gender
gender_df = pd.DataFrame(clean_mouseID_df.groupby(["Sex"]).count()).reset_index()
gender_df.head()

#Create a dataframe with Sex & MouseID from the above grouped dataframe
gender_df = gender_df[["Sex","Mouse ID"]]
gender_df.head()

#Generate pieplot
gender_df.plot(kind="pie", y = "Mouse ID", autopct='%1.1f%%',
              startangle=120, shadow=True, labels=gender_df["Sex"], legend = False, fontsize=14)

#Add title, label
plt.title('Male vs Female Mouse Population')
plt.xlabel("")
plt.ylabel("Sex", fontsize=12)

plt.axis("equal")
plt.savefig('Images/Piechart_plot')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

gender_plot = gender_df["Mouse ID"].plot.pie(y='sizes', labels=gender_df["Sex"], 
                                             figsize=(5,5), autopct="%1.1f%%",startangle=140, fontsize=14)

plt.title('Male vs Female Mouse Population', fontsize=16)
plt.ylabel('Sex', fontsize=14)

plt.axis("equal")
plt.savefig('Images/Piechart_pyplot')
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Create a subset of the clean_mouseID_df dataframe where 'Drug Regimen' is
# in [Capomulin, Ramicane, Infubinol, and Ceftamin]

drug_list_four = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

four_drugs_df = clean_mouseID_df[clean_mouseID_df['Drug Regimen'].isin(drug_list_four)]

four_drugs_df

# Start by getting the last (greatest) timepoint for each mouse
greatest_timepoint_df = clean_mouseID_df.groupby(['Mouse ID'])['Timepoint']
greatest_timepoint = greatest_timepoint_df.max()
greatest_timepoint = greatest_timepoint.reset_index()
greatest_timepoint
# Out:
#     Mouse ID  Timepoint
# 0       a203         45
# 1       a251         45
# 2       a262         45
# 3       a275         45
# 4       a366         30
# ..       ...        ...
# 243     z435         10
# 244     z578         45
# 245     z581         45
# 246     z795         45
# 247     z969         45
#
# [248 rows x 2 columns]

# %%
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
greatest_timepoint_merge = pd.merge(greatest_timepoint, clean_mouseID_df, on =('Mouse ID', 'Timepoint'), how='left')

greatest_timepoint_merge
# Out:
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0       a203         45    Infubinol  Female          20          23
# 1       a251         45    Infubinol  Female          21          25
# 2       a262         45      Placebo  Female          17          29
# 3       a275         45     Ceftamin  Female          20          28
# 4       a366         30     Stelasyn  Female          16          29
# ..       ...        ...          ...     ...         ...         ...
# 243     z435         10     Propriva  Female          12          26
# 244     z578         45     Ramicane    Male          11          16
# 245     z581         45    Infubinol  Female          24          25
# 246     z795         45     Naftisol  Female          13          29
# 247     z969         45     Naftisol    Male           9          30
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# ...

# %%
#Calculate the IQR and quantitatively determine if there are any potential outliers.

tumor_volume = []

#For loop to append drug and tumor key value pair in empty list
for drug in drug_list_four:
    
    vol = greatest_timepoint_merge.loc[greatest_timepoint_merge['Drug Regimen'] == drug]["Tumor Volume (mm3)"]
    tumor_volume.append(vol)

# Do quartile calculations for each drug

    quartiles = vol.quantile([.25,.5,.75]).round(2)
    lowerq = quartiles[0.25].round(2)
    upperq = quartiles[0.75].round(2)
    iqr = round(upperq-lowerq,2)
    lower_bound = round(lowerq - (1.5*iqr),2)
    upper_bound = round(upperq + (1.5*iqr),2)
    
    #Determine outliers 
    
    outliers = (vol.loc[(greatest_timepoint_merge['Tumor Volume (mm3)'] > upper_bound) |
                       (greatest_timepoint_merge['Tumor Volume (mm3)'] < lower_bound)])
    
    print(f"{drug}'s potential outliers: {outliers}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

fig1, ax = plt.subplots(figsize=(9,7))
ax.set_title('Final measured Tumor Volume by Drug Regimen', fontsize=16)
ax.set_xlabel('Drug Regimen', fontsize=14)
ax.set_ylabel('Final Tumor Vol (mm3)', fontsize=14)

ax.boxplot(tumor_volume,notch=0,sym='gD')

plt.xticks([1,2,3,4],drug_list_four, fontsize=14)

# Save the figure
plt.savefig("Images/BoxPlot.png")

plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# Create a dataframe for only the Capomulin data
capomulin_data = clean_mouseID_df.loc[clean_mouseID_df['Drug Regimen'] == 'Capomulin']
capomulin_data.head()


#Create a dataframe for MouseID 1509 from the Capomulin dataframe above
mouseID1509_df = capomulin_data.loc[capomulin_data["Mouse ID"] == "l509",:]
mouseID1509_df.head()

x_axis = mouseID1509_df["Timepoint"]
y_axis = mouseID1509_df["Tumor Volume (mm3)"]

#Plot linechart
plt.plot(x_axis, y_axis, linewidth=2, markersize=12)

plt.title('Capomulin treatmeant for MouseID l509', fontsize=16)
plt.xlabel('Timepoint (Days)', fontsize=14)
plt.ylabel('Tumor Volume (mm3)', fontsize=14)

plt.savefig('Images/Linechart')
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

#Find the mean values for Capomulin drug data
capomulin_avg = capomulin_data.groupby(['Mouse ID']).mean()

#Generate scatter plot
plt.scatter(capomulin_avg['Weight (g)'],capomulin_avg['Tumor Volume (mm3)'], facecolors='red', edgecolors='black')

plt.title("Mouse weight vs. Avg. Tumor Volume", fontsize=16)
plt.xlabel('Weight (g)', fontsize=14)
plt.ylabel('Average Tumor Volume (mm3)', fontsize=14)

plt.savefig('Images/Scatterplot')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
corr=round(st.pearsonr(capomulin_avg['Weight (g)'],capomulin_avg['Tumor Volume (mm3)'])[0],2)
print(f"The correlation between mouse weight and average tumor volume is {corr}")
# Out:
# The correlation between mouse weight and average tumor volume is 0.84

# %%
x_values = capomulin_avg['Weight (g)']
y_values = capomulin_avg['Tumor Volume (mm3)']

# Print out the r-squared value along with the plot.
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = f'y = {str(round(slope,2))}x + {str(round(intercept,2))}'

plt.scatter(x_values,y_values)

plt.plot(x_values, regress_values, color="red")

plt.annotate(line_eq,(18,37),fontsize=15,color="black")
plt.title("Mouse weight vs. Avg. Tumor Volume", fontsize=16)
plt.xlabel('Weight(g)', fontsize=14)
plt.ylabel('Average Tumor Volume (mm3)', fontsize=14)

print(f"The r-squared is: {rvalue}")
print(f"The equation of the regression line is: {line_eq}")

plt.savefig('Images/linearRegression')
plt.show()
# Out:
# The r-squared is: 0.8419363424694718
# The equation of the regression line is: y = 0.95x + 21.55
